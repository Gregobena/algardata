# %%
import pandas as pd 
from procesamiento import clientes, articulos

# %%
clientes.info()
clientes["Lista Precios"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5362 entries, 0 to 5361
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Código                 5362 non-null   int64
#  1   Tipo Cliente           5362 non-null   str
#  2   Nombre                 5362 non-null   str
#  3   Domicilio              5362 non-null   str
#  4   Entre calle            5362 non-null   str
#  5   y calle                5362 non-null   str
#  6   Localidad              5362 non-null   str
#  7   Cod Postal             5362 non-null   str
#  8   Provincia              5362 non-null   str
#  9   País                   5362 non-null   str
#  10  Teléfono 1             5362 non-null   str
#  11  Teléfono 2             5362 non-null   str
#  12  Fax                    5362 non-null   str
#  13  Celular                5362 non-null   str
#  14  e-mail                 5362 non-null   str
# ...

# %%
articulos.info()
articulos.value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2953 entries, 0 to 2952
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Artículo Número    2953 non-null   int64
#  1   Artículo Código    2953 non-null   str
#  2   Rubro              2953 non-null   str
#  3   Descripción        2953 non-null   str
#  4   Proveedor Nro.     2953 non-null   int64
#  5   Nombre             2953 non-null   str
#  6   Divisa Costo       2953 non-null   int64
#  7   Costo s/IVA        2953 non-null   float64
#  8   Costo c/IVA        2953 non-null   float64
#  9   Divisa Lista 1     2953 non-null   int64
#  10  Lista 1 s/IVA      2953 non-null   float64
#  11  Lista 1 c/IVA      2953 non-null   float64
#  12  Divisa Lista 2     2953 non-null   int64
#  13  Lista 2 s/IVA      2953 non-null   float64
#  14  Lista 2 c/IVA      2953 non-null   float64
#  15  Divisa Lista 3     2953 non-null   int64
# ...

# %%
articulos["Ultimo Movimiento"] = pd.to_datetime(
    articulos["Ultimo Movimiento"], 
    format="%d/%m/%Y", # Le pasamos el formato que intentaba leer
    errors='coerce'
)
fecha_inicio = '2026-01-01'
fecha_fin = '2026-05-30'

# 3. Filtrar el DataFrame
# Opción A: Usando el método .between() (súper práctico)
df_filtrado = articulos[articulos['Ultimo Movimiento'].between(fecha_inicio, fecha_fin)]
df_filtrado.head()
# Out:
#     Artículo Número Artículo Código            Rubro  \
# 25             2923         0417807      COMPUTACION
# 26             2981         0418169      COMPUTACION
# 28             1613          056122  INFRAESTRUCTURA
# 32             1230           08402  INFRAESTRUCTURA
# 49             2346     1-2111022-3  INFRAESTRUCTURA
#
#                                           Descripción  Proveedor Nro.  \
# 25               MINI PC KELYX I3-1215U 8GB M.2 256GB               8
# 26    PC KELYX AMD RYZEN 7-5700G 16GB SSD 480GB (MSI)               8
# 28       CAJA GENROD PVC CONEXION ESTANCA 210X210X165              23
# 32  CAÑO PLASTICO RIGIDO TECNOCOM BLANCO 3/4 (CRLL...              23
# 49                             FACEPLATE COMMSCOPE 2P               6
#
#                     Nombre  Divisa Costo  Costo s/IVA  Costo c/IVA  \
# 25     INVID (Jukebox S.A)             3       255.61     282.4491
# 26     INVID (Jukebox S.A)             3       498.37     550.6989
# ...
